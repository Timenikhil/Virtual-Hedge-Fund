# %% [markdown]
# <a href="https://www.quantrocket.com"><img alt="QuantRocket logo" src="https://www.quantrocket.com/assets/img/notebook-header-logo.png"></a>

# %% [markdown]
# # Welcome to QuantRocket!
# ---
# ## Step 1: Take a Tour of QuantRocket
#
# Start with this interactive tour of QuantRocket's API and JupyterLab environment.
#
# 1. [Python API first steps](Python-Intro.ipynb) - Intro to QuantRocket's Python API
# 2. [CLI first steps](CLI-Intro.ipynb) - Get to know the command line interface
# 3. [Logging first steps](Logging-Intro.ipynb) - Learn how logging works
# 4. [Clone sample code](Clone-Intro.ipynb) - Get some code into your deployment
# 5. [Code Editor](Code-Editor.ipynb) - Intro to the JupyterLab Code Editor
# 6. [Data Browser](Data-Browser.ipynb) - Browse security, price, and fundamental data in a graphical UI

# %% [markdown]
# ---
#
# ## Step 2: Activate the software
#
# Enter your free license key so you can collect sample data and explore full tutorials.
#
# * [Software activation](Activate.ipynb) - Use the Python API to enter your license key

# %% [markdown]
# ---
# ## Step 3: Explore full tutorials
#
# Visit the [Code library](https://www.quantrocket.com/code/) to find step-by-step interactive tutorials that you can clone into your own environment. The tutorials below use free sample data and can be completed without a paid QuantRocket license.

# %% [markdown]
# ### Moonshot Intro
#
# Introductory tutorial for Moonshot, QuantRocket's vectorized, pandas-based backtester. Demonstrates data collection, universe selection, and backtesting of an end-of-day momentum strategy.

# %%
# !pwd
# Out:
# /codeload/.quantrocket/quickstart

# %%
from quantrocket.codeload import clone
clone("moonshot-intro")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from quantrocket.codeload import clone
# ----> 2 clone("moonshot-intro")
#
# File /opt/conda/lib/python3.11/site-packages/quantrocket/codeload.py:114, in clone(repo, branch, replace, skip_existing, target_dir)
#     111     data["target_dir"] = target_dir
#     113 response = houston.post("/codeload/repo", data=data)
# --> 114 houston.raise_for_status_with_json(response)
#     115 status = response.json()
#     117 # If we're running in a Jupyter notebook, display a link
#     118 # to the Introduction file
#
# File /opt/conda/lib/python3.11/site-packages/quantrocket/houston.py:225, in Houston.raise_for_status_with_json(response)
#     223     e.json_response = {}
#     224     e.args = e.args + ("please check the logs for more details",)
# --> 225 raise e
#
# File /opt/conda/lib/python3.11/site-packages/quantrocket/houston.py:217, in Houston.raise_for_status_with_json(response)
#     212 """
#     213 Raises 400/500 error codes, attaching a json response to the
#     214 exception, if possible.
#     215 """
#     216 try:
# --> 217     response.raise_for_status()
#     218 except requests.exceptions.HTTPError as e:
#     219     try:
#
# File /opt/conda/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: ('400 Client Error: BAD REQUEST for url: http://houston/codeload/repo', {'status': 'error', 'msg': 'one or more files will be overwritten, please specify replace or skip_existing', 'files': {'conflict': ['intro_moonshot/Introduction.ipynb', 'intro_moonshot/Part1-Historical-Data-Collection.ipynb', 'intro_moonshot/Part2-Universe-Selection.ipynb', 'intro_moonshot/Part3-Momentum-Factor-Research.ipynb', 'intro_moonshot/Part4-Moonshot-Strategy-Code.ipynb', 'intro_moonshot/Part5-Moonshot-Backtest.ipynb', 'intro_moonshot/Part6-Moonshot-Parameter-Scans.ipynb', 'intro_moonshot/Part7-Debug-Moonshot-Strategies.ipynb', 'intro_moonshot/__init__.py']}})

# %% [markdown]
# ### Zipline Intro
#
# Introductory tutorial for Zipline, the popular backtester that originally powered Quantopian. Demonstrates data collection, interactive research, and backtesting of a momentum strategy for equities.

# %%
from quantrocket.codeload import clone
clone("zipline-intro")

# %% [markdown]
# After completing the Zipline tutorial, dive deeper into the Pipeline API with the Pipeline tutorial:

# %%
from quantrocket.codeload import clone
clone("pipeline-tutorial")

# %% [markdown]
# ### Quant Finance Lectures
#
# Learn quantitative finance with this comprehensive lecture series. Adapted for QuantRocket from the Quantopian Lecture Series.

# %%
from quantrocket.codeload import clone
clone("quant-finance-lectures")

# %% [markdown]
# ### MoonshotML Intro
#
# Introductory tutorial for MoonshotML demonstrating walk-forward optimization of a simple machine learning strategy. MoonshotML is built on top of Moonshot, so complete the Moonshot Intro tutorial before attempting this tutorial.

# %%
from quantrocket.codeload import clone
clone("moonshotml-intro")

# %% [markdown]
# ### Intraday FX Strategy
#
# This tutorial demonstrates an intraday FX strategy that exploits the tendency of currencies to depreciate during local business hours and appreciate during foreign business hours. Uses EUR.USD with hourly data from Interactive Brokers. Requires an Interactive Brokers account.

# %%
from quantrocket.codeload import clone
clone("fx-bizday")
