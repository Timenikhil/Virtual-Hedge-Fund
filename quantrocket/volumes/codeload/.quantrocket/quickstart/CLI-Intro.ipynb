# %% [markdown]
# <a href="https://www.quantrocket.com"><img alt="QuantRocket logo" src="https://www.quantrocket.com/assets/img/notebook-header-logo.png"></a>

# %% [markdown]
# # CLI First Steps
#
# *Get to know the command line interface*

# %% [markdown]
# To access the command line interface, open a Terminal from the JupyterLab Launcher (or from File > New > Terminal).
#
# <img src="https://www.quantrocket.com/assets/img/quickstart/jupyter-terminal.gif">
#
# > Tip: You can drag the terminal window to dock it beside or below this notebook so that you can view both.
#
# You can find your way through the command line interface (CLI) by making use of the `-h/--help` option with any command or subcommand. Try typing the following commands (press `Enter` to execute a command):
#
# ```
# quantrocket -h
# quantrocket master -h
# quantrocket master calendar -h
# ```
#
# The CLI provides autocomplete suggestions as you type. Press → (right arrow) to accept
# the suggestion, or press `Tab` to see more choices. Let's run the command that corresponds to the Python function you ran  a moment ago. To demonstrate autocomplete, suppose you can't remember the MIC for the New York Stock Exchange. Type the command without the exchange code, as shown below, then press `Tab`:
#
# ```shell
# quantrocket master calendar <TAB>
# ```
#
# An autocomplete menu of available exchange codes will appear below the command. Use the arrow keys to select `XNYS` from the menu and press `Enter` to autofill it into the command.
#
# Most commands provide a number of options which start with a hyphen (`-`) and which correspond to the function parameters of the Python API. To see all available options for a command, you can use `-h`/`--help` as shown above or type a hyphen as shown below and press `Tab`. Try it:
#
# ```shell
# quantrocket master calendar 'XNYS' -<TAB>
# ```
#
# The autocomplete menu appears again, this time with a list of available command options. Select `--ago` from the menu so that the command now looks like this, then press `Tab` again:
#
# ```shell
# quantrocket master calendar 'XNYS' --ago <TAB>
# ```
#
# This time, pressing `<Tab>` will bring up a menu of example values for the `--ago` option. For this option, we don't see all possible values but only a few example values. You can choose a value from the menu or type your own, then press `Enter` to execute the full command:
#
# ```shell
# quantrocket master calendar 'XNYS' --ago '2h'
# ```
#
# *(Placing quotes around options as shown above ('XNYS') is only required if the values contain spaces or special characters. However, quotes are used in the documentation to improve readability even when they aren't required.)*

# %% [markdown]
# ## Using the Terminal directly from Notebooks
#
# The best way to use the CLI is to open a Terminal, but you can also execute terminal commands directly from within notebooks by prefixing the line with an exclamation point (`!`). You'll see this syntax used sometimes in QuantRocket demo notebooks where the CLI seems more natural than the Python API.
#
# Execute the following cell to see this in action:

# %%
# !quantrocket master calendar 'XNYS' --in '1d'
# Out:
# XNYS:
#   since: '2024-09-13T16:00:00'
#   status: closed
#   timezone: America/New_York
#   until: '2024-09-16T09:30:00'

# %% [markdown]
# ***
#
# ## *Next Up*
#
# [Logging first steps](Logging-Intro.ipynb) - Learn how logging works in QuantRocket
